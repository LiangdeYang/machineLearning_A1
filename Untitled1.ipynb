# %%
import h5py
import numpy as np
np.set_printoptions(suppress = True)
import scipy as sci
import matplotlib.pyplot as plt
import operator
import math
import time

# %%
y = [15.55, 15.65, 15.45, 15.70, 15.35, 15.45, 15.25, 15.20, 16.05, 16.40]

y2 = [55.60, 55.35,55.65,55.80, 55.40, 55.90, 56.00, 55.15, 55.65, 57.40]

x =[100,90,80,70,60,50,40,30,20,10]
xint = np.arange(np.min(x)-10, np.max(x)+10, 10)
plt.xticks(xint)

plt.xlabel('number of principle components')
yt = np.arange(np.min(y), np.max(y)+1, 0.2)
#plt.yticks(yt)
plt.ylabel('Accuracy %')
plt.title('Accuracy vs different number of principle components');

plt.axis([0,100, 0,80])
plt.plot(x,y,)
plt.plot(x,y2,)
plt.legend(['my_pca', 'sklearn_pca',], loc='upper left')




plt.show()
